# %% [markdown]
# # Targeted miRNA Expression ROC/AUC Analysis
# ### Esophageal Squamous Cell Carcinoma (tumor vs adjacent normal)
# **Focus:** ROC & AUC for a predefined panel of 45 miRNAs
#
# ---
# **Pipeline:**
# 1. Install & import
# 2. Target miRNA list
# 3. Download GEO dataset
# 4. Inspect dataset
# 5. Extract phenotype labels
# 6. Build & preprocess expression matrix
# 7. Map probes → miRNA names
# 8. ROC/AUC per target miRNA
# 9. Individual ROC curve grid

# %% [markdown]
# ## 1. Import

# %%
import os, warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import seaborn as sns
import GEOparse

from scipy import stats
from sklearn.metrics import roc_curve, auc
from matplotlib.lines import Line2D

# ── Shared style ──
DPI     = 500
PALETTE = {"disease": "#E63946", "control": "#457B9D"}

plt.rcParams.update({
    "figure.dpi":        150,
    "axes.spines.top":   False,
    "axes.spines.right": False,
    "font.size":         11,
})

OUTDIR = "./results"
os.makedirs(OUTDIR, exist_ok=True)

# %% [markdown]
# ## 2. Target miRNA List

# %%
TARGET_MIRNAS_RAW = [
    "hsa-miR-152-3p", "hsa-miR-106b-5p", "hsa-miR-27a-3p",  "hsa-miR-17-3p",
    "hsa-miR-23a-3p", "hsa-miR-34a-5p",  "hsa-miR-15b-5p",  "hsa-miR-3529-3p",
    "hsa-miR-3613-5p","hsa-miR-185-5p",  "hsa-miR-29b-3p",  "hsa-miR-9985",
    "hsa-miR-542-5p", "hsa-miR-590-3p",  "hsa-miR-362-5p",  "hsa-miR-450a-5p",
    "hsa-miR-455-3p", "hsa-miR-451a",    "hsa-miR-424-5p",  "hsa-miR-223-3p",
    "hsa-miR-20a-3p", "hsa-miR-18a-5p",  "hsa-miR-503-5p",  "hsa-miR-140-5p",
    "hsa-miR-22-5p",  "hsa-miR-7-5p",    "hsa-miR-144-3p",  "hsa-miR-4448",
    "hsa-miR-4531",   "hsa-miR-4739",    "hsa-miR-3907",    "hsa-miR-6131",
    "hsa-miR-7704",   "hsa-miR-3135b",   "hsa-miR-4634",    "hsa-miR-6765-3p",
    "hsa-miR-4770",   "hsa-miR-4746-5p", "hsa-miR-16-5p",   "hsa-miR-142-3p",
    "hsa-miR-374a-5p","hsa-let-7f-1-3p", "hsa-miR-374b-5p", "hsa-miR-28-3p",
    "hsa-miR-378c"
]

def normalize_mirna(name):
    name = name.strip()
    if not name.startswith("hsa-"):
        name = ("hsa-let-" + name[4:]) if name.startswith("let-") else ("hsa-" + name)
    return name.lower()

TARGET_MIRNAS = list(dict.fromkeys(normalize_mirna(m) for m in TARGET_MIRNAS_RAW))

# %% [markdown]
# ## 3. Download GEO dataset

# %%
DESTDIR = "./geo_data"
os.makedirs(DESTDIR, exist_ok=True)

try:
    gse = GEOparse.get_GEO("GSE114110", destdir=DESTDIR, silent=False)
    
except Exception as e:
    print(f"\n✗ Download failed: {e}")
    raise

# %% [markdown]
# ## 4. Inspect Dataset

# %%
for k in ["Series_title", "Series_summary", "Series_platform_id"]:
    val = gse.metadata.get(k, ["N/A"])
    val = val if isinstance(val, list) else [val]
    print(f"\n{k}:")
    for v in val[:2]:
        print(f"  {v[:300]}")

print(f"\nTotal samples : {len(gse.gsms)}")
print(f"Platform(s)   : {list(gse.gpls.keys())}")

pheno = gse.phenotype_data.copy()
print("\nPhenotype columns:")
for col in pheno.columns:
    print(f"  [{col}]: {pheno[col].unique()[:3]}")

# %% [markdown]
# ## 5. Extract Phenotype Labels

# %%
CONTROL_KW = ["normal","control","healthy","adjacent","non-tumor","para",
              "benign","noncancer","non-cancer","uninvolved","donor","matched"]
DISEASE_KW = ["tumor","cancer","carcinoma","adenocarcinoma","malignant",
              "squamous","sarcoma","leukemia","lymphoma","melanoma",
              "glioma","hepato","gastric","affected"]

condition_col = None
best_score    = 0
for col in pheno.columns:
    vals_str = " ".join(str(v).lower() for v in pheno[col].dropna().unique())
    score = (sum(kw in vals_str for kw in DISEASE_KW) +
             sum(kw in vals_str for kw in CONTROL_KW))
    if score > best_score and 2 <= len(pheno[col].dropna().unique()) <= 10:
        best_score    = score
        condition_col = col

print(f"✓ Auto-detected column: '{condition_col}'")
print(f"  Values: {pheno[condition_col].unique()}")
CONDITION_COL = condition_col   # ← override manually if wrong

# %%
def map_label(val):
    v = str(val).lower()
    if any(kw in v for kw in CONTROL_KW):   # control FIRST
        return 0
    elif any(kw in v for kw in DISEASE_KW):
        return 1
    return np.nan

labels = pheno[CONDITION_COL].map(map_label)

print("Label mapping:")
for val in pheno[CONDITION_COL].unique():
    mapped = map_label(val)
    sym = {0: "→ 0 (Control)", 1: "→ 1 (Disease)"}.get(mapped, "→ ⚠ UNMAPPED")
    print(f"  {sym}  |  {val}")

labels = labels.dropna().astype(int)
print(f"\n0 = Control : {(labels==0).sum()} samples")
print(f"1 = Disease : {(labels==1).sum()} samples")
print(f"Total       : {len(labels)} samples")

# %% [markdown]
# ## 6. Build & Preprocess Expression Matrix

# %%
expr_data = {}
for gsm_name, gsm in gse.gsms.items():
    if gsm_name in labels.index:
        try:
            s = gsm.table.set_index("ID_REF")["VALUE"].astype(float)
            expr_data[gsm_name] = s
        except Exception as e:
            print(f"  ⚠ Skipped {gsm_name}: {e}")

expr   = pd.DataFrame(expr_data)
common = [s for s in expr.columns if s in labels.index]
expr   = expr[common]
labels = labels.loc[common]
print(f"✓ Raw matrix: {expr.shape[0]} probes × {expr.shape[1]} samples")

# NA filter → log2 → quantile normalisation
na_frac = expr.isnull().mean(axis=1)
expr    = expr.loc[na_frac <= 0.20]
expr    = expr.apply(lambda row: row.fillna(row.median()), axis=1)
print(f"After NA filter    : {expr.shape[0]} probes")

min_val = expr.min().min()
expr    = np.log2(expr - min_val + 1) if min_val <= 0 else np.log2(expr + 1)
print("Log2 transform     : done")

def quantile_normalize(df):
    rank_mean = df.stack().groupby(df.rank(method="first").stack().astype(int)).mean()
    return df.rank(method="min").stack().astype(int).map(rank_mean).unstack()

expr = quantile_normalize(expr)
print("Quantile normalize : done")
print(f"Final matrix       : {expr.shape[0]} probes × {expr.shape[1]} samples")

# %% [markdown]
# ## 7. Map Probes → miRNA Names

# %%
gpl_id = list(gse.gpls.keys())[0]
gpl    = gse.gpls[gpl_id]
print(f"Platform: {gpl_id}")
print(f"GPL columns: {gpl.table.columns.tolist()}")
gpl.table.head(3)

# %%
name_col = None
for col in gpl.table.columns:
    sample_vals = gpl.table[col].dropna().astype(str)
    if sample_vals.str.contains("miR|let-7", case=False, na=False).sum() > 10:
        name_col = col
        print(f"✓ miRNA name column: '{name_col}'")
        break

if name_col is None:
    print("⚠ Could not auto-detect name column.")
    print("Available columns:", gpl.table.columns.tolist())
    name_col = "miRNA_ID"   # ← change manually if needed

id_col = "ID" if "ID" in gpl.table.columns else gpl.table.columns[0]
anno   = gpl.table[[id_col, name_col]].copy()
anno.columns = ["probe_id", "mirna_name"]
anno["mirna_name_lower"] = anno["mirna_name"].astype(str).str.lower().str.strip()
anno = anno.dropna(subset=["mirna_name"])

matched   = {}
unmatched = []

for mirna in TARGET_MIRNAS:
    hits = anno[anno["mirna_name_lower"] == mirna]["probe_id"].tolist()
    hits = [p for p in hits if p in expr.index]
    if hits:
        matched[mirna] = hits
    else:
        unmatched.append(mirna)

print(f"✓ Matched   : {len(matched)} / {len(TARGET_MIRNAS)} miRNAs")
print(f"✗ Unmatched : {len(unmatched)} miRNAs")
if unmatched:
    for m in unmatched: print(f"    {m}")

# %% [markdown]
# ## 8. ROC/AUC per Target miRNA

# %%
y = labels.values

roc_results = []

for mirna, probes in matched.items():
    if len(probes) == 1:
        x = expr.loc[probes[0], labels.index].values.astype(float)
    else:
        sub  = expr.loc[probes, labels.index]
        best = sub.var(axis=1).idxmax()
        x    = sub.loc[best].values.astype(float)

    fpr, tpr, _ = roc_curve(y, x)
    roc_auc     = auc(fpr, tpr)
    flipped = False
    if roc_auc < 0.5:
        fpr, tpr, _ = roc_curve(y, -x)
        roc_auc     = auc(fpr, tpr)
        flipped     = True

    log2fc = x[y==1].mean() - x[y==0].mean()
    _, pval = stats.ttest_ind(x[y==1], x[y==0], equal_var=False)

    roc_results.append({
        "miRNA":     mirna,
        "probes":    ", ".join(probes[:3]),
        "n_probes":  len(probes),
        "AUC":       roc_auc,
        "log2FC":    log2fc,
        "p_value":   pval,
        "direction": "Up" if log2fc > 0 else "Down",
        "flipped":   flipped,
        "fpr":       fpr,
        "tpr":       tpr,
    })

results_df = pd.DataFrame(
    [{k:v for k,v in r.items() if k not in ["fpr","tpr"]} for r in roc_results]
).sort_values("AUC", ascending=False).reset_index(drop=True)

print(f"✓ ROC/AUC computed for {len(results_df)} miRNAs\n")
results_df[["miRNA","AUC","log2FC","p_value","direction","n_probes"]]

# %% [markdown]
# ## 9. Individual ROC Curve Grid

# %%
n_mirnas = len(roc_results)
n_cols   = 4
n_rows   = int(np.ceil(n_mirnas / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 3.5, n_rows * 3.2))
axes = axes.flatten()

for i, res in enumerate(sorted(roc_results, key=lambda r: r["AUC"], reverse=True)):
    ax    = axes[i]
    color = PALETTE["disease"] if res["log2FC"] > 0 else PALETTE["control"]
    ax.plot(res["fpr"], res["tpr"], lw=2, color=color)
    ax.plot([0, 1], [0, 1], "k--", lw=0.8, alpha=0.4)
    ax.set_title(res["miRNA"].replace("hsa-", ""), fontsize=10, fontweight="bold")
    ax.text(0.97, 0.07, f"AUC={res['AUC']:.3f}", transform=ax.transAxes,
            ha="right", fontsize=9, color=color,
            bbox=dict(boxstyle="round,pad=0.2", fc="white", ec=color, alpha=0.8))
    ax.set_xlabel("False Positive Rate", fontsize=8)
    ax.set_ylabel("True Positive Rate", fontsize=8)
    ax.set_xticks([0, 0.5, 1]); ax.set_yticks([0, 0.5, 1])

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

fig.suptitle("ROC Curves — miRNA Panel\n (Esophageal Squamous Cell Carcinoma)",
             fontsize=13, fontweight="bold", y=1.01)
plt.tight_layout()
for ext in ("png", "tiff"):
    plt.savefig(f"{OUTDIR}/ROC_grid.{ext}", dpi=DPI, bbox_inches="tight")
plt.show()
print("✓ Saved: ROC_grid .png / .tiff")

# %%
for res in sorted(roc_results, key=lambda r: r["AUC"], reverse=True):
    fig, ax = plt.subplots(figsize=(4, 4))
    color = PALETTE["disease"] if res["log2FC"] > 0 else PALETTE["control"]
    ax.plot(res["fpr"], res["tpr"], lw=2, color=color)
    ax.plot([0, 1], [0, 1], "k--", lw=0.8, alpha=0.4)
    ax.set_title(res["miRNA"].replace("hsa-", ""), fontsize=10, fontweight="bold")
    ax.text(0.97, 0.07, f"AUC={res['AUC']:.3f}", transform=ax.transAxes,
            ha="right", fontsize=9, color=color,
            bbox=dict(boxstyle="round,pad=0.2", fc="white", ec=color, alpha=0.8))
    ax.set_xlabel("False Positive Rate", fontsize=8)
    ax.set_ylabel("True Positive Rate", fontsize=8)
    ax.set_xticks([0, 0.5, 1]); ax.set_yticks([0, 0.5, 1])
    plt.tight_layout()
    safe_name = res["miRNA"].replace("hsa-", "").replace("/", "_")
    for ext in ("png", "tiff"):
        plt.savefig(f"{OUTDIR}/ROC_{safe_name}.{ext}", dpi=DPI, bbox_inches="tight")
    plt.close()

print(f"✓ Saved {len(roc_results)} individual ROC figures to {OUTDIR}")
